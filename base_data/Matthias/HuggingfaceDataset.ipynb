# %% [markdown]
# # Building a Huggingface `DatasetDict` for the *gNER* dataset
# **Tidy up and polish everything!**<br>
# The resulting dataset is stored in the folder *gNERdataset* and can be loaded via `load_from_disk("gNERdataset")`. However, the `ClassLabel` list with the names of the NER tags is not available anymore when loading from disk!

# %%
import json
from datasets import Dataset

with open("./annotations2.jsonl") as jsonl_file: # . instead of ..
    lines = jsonl_file.readlines()
annot = [json.loads(line) for line in lines]
print("instances:\n{}".format(len(annot)))
keys = [key for key in annot[0].keys()]
print("\nall keys:\n{}".format(keys))
key_keys = ["text", "spans", "tokens"]
print("\nimportant keys:\n{}".format(key_keys))
print("\nexample text:\n{}".format(annot[0]["text"]))
n_examples = 5
print("\n{} example spans:".format(n_examples))
for span in annot[0]["spans"][:n_examples]:
    print("{}".format(span))
print("\n{} example tokens:".format(n_examples))
for token in annot[0]["tokens"][:n_examples]:
    print("{}".format(token))
# Out:
# instances:
# 140
#
# all keys:
# ['text', 'meta', '_input_hash', '_task_hash', 'spans', 'tokens', '_view_id', 'answer', '_timestamp']
#
# important keys:
# ['text', 'spans', 'tokens']
#
# example text:
# DORNBIRN In der Schulgasse in Dornbirn hat eine 71,93 Quadratmeter große Wohnung für einen Quadratmeterpreis von 5533,71 Euro den Besitzer gewechselt. Dieser beinhaltet auch einen Pkw-Abstellplatz. Käufer der Wohnung mit 9,86 Quadratmetern Terrasse ist die ValLiLean Beteiligungs- und Immobilienverwaltungs GmbH. Beim Verkäufer handelt es sich um die Karrenblick Projekt GmbH.  Der Kaufpreis liegt bei 398.040 Euro. Unterzeichnet wurde der Kaufvertrag am 18. September. Die Verbücherung datiert mit Oktober 2020.
#
# 5 example spans:
# {'text': 'DORNBIRN', 'start': 0, 'end': 8, 'pattern': 2069086582, 'token_start': 0, 'token_end': 0, 'label': 'ORT', 'noWords': 1}
# {'start': 16, 'end': 26, 'token_start': 3, 'token_end': 3, 'label': 'STRASSE', 'noWords': 1}
# {'text': 'Dornbirn', 'start': 30, 'end': 38, 'pattern': 2069086582, 'token_start': 5, 'token_end': 5, 'label': 'ORT', 'noWords': 1}
# {'start': 48, 'end': 53, 'token_start': 8, 'token_end': 8, 'label': 'FLAECHE', 'noWords': 1}
# {'start': 73, 'end': 80, 'token_start': 11, 'token_end': 11, 'label': 'IMMO_TYP', 'noWords': 1}
#
# 5 example tokens:
# {'text': 'DORNBIRN', 'start': 0, 'end': 8, 'id': 0, 'ws': True, 'label': 'ORT'}
# {'text': 'In', 'start': 9, 'end': 11, 'id': 1, 'ws': True, 'label': 'O'}
# {'text': 'der', 'start': 12, 'end': 15, 'id': 2, 'ws': True, 'label': 'O'}
# {'text': 'Schulgasse', 'start': 16, 'end': 26, 'id': 3, 'ws': True, 'label': 'STRASSE'}
# {'text': 'in', 'start': 27, 'end': 29, 'id': 4, 'ws': True, 'label': 'O'}

# %%
def getLabel(tokenDictList, idx):
    result = "O"
    for dict_i in tokenDictList:
        idx_0, idx_1 = dict_i["start"], dict_i["end"]
        if (idx_0<=idx) and (idx<=idx_1):
            result = dict_i["label"]
    return result 

for j in range(len(annot)): # loop over instances
    a = annot[j]            # instance j
    spans = a["spans"]      # list of annotation dicts
    toks = a["tokens"]      # list of token dicts
    for i in range(len(toks)):                                 # loop over token dicts
        toks[i]["label"] = getLabel(spans, toks[i]["start"])   # assign label from span (if exists, otherwise "O")
    annot[j]["tokens"] = toks

words_n = 3
for i in range(2):
    print("Token dictionaries for the last {} words of instance {}".format(words_n, i))
    ann = annot[i]
    for tok in ann["tokens"][:words_n]:
        print(tok)
# Out:
# Token dictionaries for the last 3 words of instance 0
# {'text': 'DORNBIRN', 'start': 0, 'end': 8, 'id': 0, 'ws': True, 'label': 'ORT'}
# {'text': 'In', 'start': 9, 'end': 11, 'id': 1, 'ws': True, 'label': 'O'}
# {'text': 'der', 'start': 12, 'end': 15, 'id': 2, 'ws': True, 'label': 'O'}
# Token dictionaries for the last 3 words of instance 1
# {'text': 'FELDKIRCH', 'start': 0, 'end': 9, 'id': 0, 'ws': True, 'label': 'ORT'}
# {'text': 'Im', 'start': 10, 'end': 12, 'id': 1, 'ws': True, 'label': 'O'}
# {'text': 'Altenreuteweg', 'start': 13, 'end': 26, 'id': 2, 'ws': True, 'label': 'STRASSE'}

# %%
sents=[] 
for annot_i in annot:                  # loop over instances
    toks = annot_i['tokens']           # get tokens list for instance i
    train_sentence = []
    for tok in toks:                   # loop over token dicts
        if 'label' in tok:             # only if the current token has been labelled, ...
            token_element = (tok['text'], tok['label']) # ... create a "text", "label" pair for this token ...
            train_sentence.append(token_element)        # ... and append it to the list
    sents.append(train_sentence) # append the list for that instances to the list for all instances / sentences

# list of lists of pairs (sets): outer list contains instances and inner list contains (token, label) pairs
sents[:2]
# Out:
# [[('DORNBIRN', 'ORT'),
#   ('In', 'O'),
#   ('der', 'O'),
#   ('Schulgasse', 'STRASSE'),
#   ('in', 'O'),
#   ('Dornbirn', 'ORT'),
#   ('hat', 'O'),
#   ('eine', 'O'),
#   ('71,93', 'FLAECHE'),
#   ('Quadratmeter', 'O'),
#   ('große', 'O'),
#   ('Wohnung', 'IMMO_TYP'),
#   ('für', 'O'),
#   ('einen', 'O'),
#   ('Quadratmeterpreis', 'O'),
#   ('von', 'O'),
#   ('5533,71', 'QMPREIS'),
#   ('Euro', 'O'),
#   ('den', 'O'),
#   ('Besitzer', 'O'),
#   ('gewechselt', 'O'),
#   ('.', 'O'),
#   ('Dieser', 'O'),
#   ('beinhaltet', 'O'),
#   ('auch', 'O'),
#   ('einen', 'O'),
#   ('Pkw-Abstellplatz', 'O'),
#   ('.', 'O'),
#   ('Käufer', 'O'),
#   ('der', 'O'),
#   ('Wohnung', 'O'),
#   ('mit', 'O'),
#   ('9,86', 'TERRASSENGROESSE'),
#   ('Quadratmetern', 'O'),
#   ('Terrasse', 'O'),
#   ('ist', 'O'),
#   ('die', 'O'),
#   ('ValLiLean', 'KAEUFER'),
#   ('Beteiligungs-', 'KAEUFER'),
#   ('und', 'KAEUFER'),
#   ('Immobilienverwaltungs', 'KAEUFER'),
#   ('GmbH', 'KAEUFER'),
#   ('.', 'KAEUFER'),
#   ('Beim', 'O'),
#   ('Verkäufer', 'O'),
#   ('handelt', 'O'),
#   ('es', 'O'),
#   ('sich', 'O'),
#   ('um', 'O'),
#   ('die', 'O'),
#   ('Karrenblick', 'VERKAEUFER'),
#   ('Projekt', 'VERKAEUFER'),
#   ('GmbH', 'VERKAEUFER'),
#   ('.', 'VERKAEUFER'),
#   (' ', 'O'),
#   ('Der', 'O'),
#   ('Kaufpreis', 'O'),
#   ('liegt', 'O'),
#   ('bei', 'O'),
#   ('398.040', 'GESAMTPREIS'),
#   ('Euro', 'O'),
#   ('.', 'O'),
#   ('Unterzeichnet', 'O'),
#   ('wurde', 'O'),
#   ('der', 'O'),
#   ('Kaufvertrag', 'O'),
#   ('am', 'O'),
#   ('18.', 'DATUM_VERTRAG'),
#   ('September', 'DATUM_VERTRAG'),
#   ('.', 'DATUM_VERTRAG'),
#   ('Die', 'O'),
#   ('Verbücherung', 'O'),
#   ('datiert', 'O'),
#   ('mit', 'O'),
#   ('Oktober', 'DATUM_VERBUECHERUNG'),
#   ('2020', 'DATUM_VERBUECHERUNG'),
#   ('.', 'DATUM_VERBUECHERUNG')],
#  [('FELDKIRCH', 'ORT'),
#   ('Im', 'O'),
#   ('Altenreuteweg', 'STRASSE'),
#   ('in', 'O'),
#   ('Feldkirch', 'ORT'),
#   ('hat', 'O'),
#   ('eine', 'O'),
#   ('100,67', 'FLAECHE'),
#   ('Quadratmeter', 'O'),
#   ('große', 'O'),
#   ('Wohnung', 'IMMO_TYP'),
#   ('für', 'O'),
#   ('einen', 'O'),
#   ('Quadratmeterpreis', 'O'),
#   ('von', 'O'),
#   ('6168,67', 'QMPREIS'),
#   ('Euro', 'O'),
#   ('den', 'O'),
#   ('Besitzer', 'O'),
#   ('gewechselt', 'O'),
#   ('.', 'O'),
#   ('Käufer', 'O'),
#   ('der', 'O'),
#   ('Wohnung', 'O'),
#   ('mit', 'O'),
#   ('einer', 'O'),
#   ('137,49', 'TERRASSENGROESSE'),
#   ('Quadratmeter', 'O'),
#   ('großen', 'O'),
#   ('Terrasse', 'O'),
#   ('ist', 'O'),
#   ('eine', 'O'),
#   ('Privatperson', 'KAEUFER'),
#   ('.', 'KAEUFER'),
#   ('Beim', 'O'),
#   ('Verkäufer', 'O'),
#   ('handelt', 'O'),
#   ('es', 'O'),
#   ('sich', 'O'),
#   ('um', 'O'),
#   ('die', 'O'),
#   ('Rüscher', 'VERKAEUFER'),
#   ('und', 'VERKAEUFER'),
#   ('Söhne', 'VERKAEUFER'),
#   ('Bau', 'VERKAEUFER'),
#   ('GmbH', 'VERKAEUFER'),
#   ('&', 'VERKAEUFER'),
#   ('Co', 'VERKAEUFER'),
#   ('KG', 'VERKAEUFER'),
#   ('.', 'VERKAEUFER'),
#   (' ', 'O'),
#   ('Der', 'O'),
#   ('Kaufpreis', 'O'),
#   ('liegt', 'O'),
#   ('bei', 'O'),
#   ('621.000', 'GESAMTPREIS'),
#   ('Euro', 'O'),
#   ('.', 'O'),
#   ('Unterzeichnet', 'O'),
#   ('wurde', 'O'),
#   ('der', 'O'),
#   ('Kaufvertrag', 'O'),
#   ('am', 'O'),
#   ('11.', 'DATUM_VERTRAG'),
#   ('August', 'DATUM_VERTRAG'),
#   ('.', 'DATUM_VERTRAG'),
#   ('Die', 'O'),
#   ('Verbücherung', 'O'),
#   ('datiert', 'O'),
#   ('mit', 'O'),
#   ('September', 'DATUM_VERBUECHERUNG'),
#   ('2020', 'DATUM_VERBUECHERUNG'),
#   ('.', 'DATUM_VERBUECHERUNG')]]

# %%
# 1. build tokens = list of lists of tokens
# 2. build labels = list of lists of labels
words = []
ner_tags = []
for sent_i in sents:
    words_i = []
    ner_tags_i = []
    for item in sent_i:
        words_i.append(item[0])
        ner_tags_i.append(item[1])
    words.append(words_i)
    ner_tags.append(ner_tags_i)

dataset = Dataset.from_dict({"words": words, "ner_tags": ner_tags})
dataset
# Out:
# Dataset({
#     features: ['words', 'ner_tags'],
#     num_rows: 140
# })

# %%
# set of labels
ner_tag_names = sorted(list(set([ner_tag_ij for ner_tags_i in ner_tags for ner_tag_ij in ner_tags_i])))
ner_tag_names
# Out:
# ['DATUM_VERBUECHERUNG',
#  'DATUM_VERTRAG',
#  'FLAECHE',
#  'GESAMTPREIS',
#  'IMMO_TYP',
#  'KAEUFER',
#  'O',
#  'ORT',
#  'QMPREIS',
#  'STRASSE',
#  'TERRASSENGROESSE',
#  'VERKAEUFER']

# %%
# tokenize and adjust labels
from transformers import AutoTokenizer
checkpoint = "flair/ner-german"  # https://huggingface.co/flair/ner-german (1.41GB)
checkpoint = "fhswf/bert_de_ner" # https://huggingface.co/fhswf/bert_de_ner (419MB)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
tokenizer.is_fast
# Out:
# True

# %%
def align_labels_with_tokens(ner_tags, word_ids):
    #print(word_ids)
    new_labels = []
    previous_label = None
    previous_word_id = None
    for word_id in word_ids:
        # handle word_id==None
        if word_id==None:
            label = -100
        # handle word_id==previous_word_id
        elif word_id==previous_word_id:
            label = previous_label
        # handle word_id!=previous_word_id and word_id!=None
        else:
            text_label = ner_tags[word_id]
            label = ner_tag_names.index(text_label)
        new_labels.append(label)
        previous_label = label
        previous_word_id = word_id
    return new_labels

instance = 5 # 118 => goal = [-100]
ner_tags = dataset[instance]["ner_tags"]
word_ids = tokenizer(dataset[instance]["words"], is_split_into_words=True).word_ids()
aligned_labels = align_labels_with_tokens(ner_tags, word_ids)
inputs = tokenizer(dataset[instance]["words"], is_split_into_words=True)
for i, token in enumerate(inputs.tokens()):
    alabel = aligned_labels[i]
    tlabel = ner_tag_names[alabel] if alabel>=0 else "SPECIAL TOKEN"
    print(f"index: {i}\ttoken: {token}\tword_id: {word_ids[i]}\taligned label: {alabel}\ttext label: {tlabel}")
len(inputs.tokens()), len(aligned_labels), len(word_ids)
# Out:
# index: 0	token: [CLS]	word_id: None	aligned label: -100	text label: SPECIAL TOKEN
# index: 1	token: ko	word_id: 0	aligned label: 7	text label: ORT
# index: 2	token: ##bl	word_id: 0	aligned label: 7	text label: ORT
# index: 3	token: ##ach	word_id: 0	aligned label: 7	text label: ORT
# index: 4	token: im	word_id: 1	aligned label: 6	text label: O
# index: 5	token: ber	word_id: 2	aligned label: 9	text label: STRASSE
# index: 6	token: ##eich	word_id: 2	aligned label: 9	text label: STRASSE
# index: 7	token: no	word_id: 3	aligned label: 9	text label: STRASSE
# index: 8	token: ##llen	word_id: 3	aligned label: 9	text label: STRASSE
# index: 9	token: in	word_id: 4	aligned label: 6	text label: O
# index: 10	token: ko	word_id: 5	aligned label: 7	text label: ORT
# index: 11	token: ##bl	word_id: 5	aligned label: 7	text label: ORT
# index: 12	token: ##ach	word_id: 5	aligned label: 7	text label: ORT
# index: 13	token: hat	word_id: 6	aligned label: 6	text label: O
# index: 14	token: ein	word_id: 7	aligned label: 6	text label: O
# index: 15	token: grund	word_id: 8	aligned label: 4	text label: IMMO_TYP
# index: 16	token: ##stu	word_id: 8	aligned label: 4	text label: IMMO_TYP
# index: 17	token: ##ck	word_id: 8	aligned label: 4	text label: IMMO_TYP
# index: 18	token: den	word_id: 9	aligned label: 6	text label: O
# index: 19	token: bes	word_id: 10	aligned label: 6	text label: O
# index: 20	token: ##itzer	word_id: 10	aligned label: 6	text label: O
# index: 21	token: gewechselt	word_id: 11	aligned label: 6	text label: O
# index: 22	token: .	word_id: 12	aligned label: 6	text label: O
# index: 23	token: verkauft	word_id: 13	aligned label: 6	text label: O
# index: 24	token: wurde	word_id: 14	aligned label: 6	text label: O
# index: 25	token: der	word_id: 15	aligned label: 6	text label: O
# index: 26	token: grund	word_id: 16	aligned label: 4	text label: IMMO_TYP
# index: 27	token: um	word_id: 17	aligned label: 6	text label: O
# index: 28	token: 66	word_id: 18	aligned label: 3	text label: GESAMTPREIS
# index: 29	token: ##5	word_id: 18	aligned label: 3	text label: GESAMTPREIS
# index: 30	token: .	word_id: 18	aligned label: 3	text label: GESAMTPREIS
# index: 31	token: 000	word_id: 18	aligned label: 3	text label: GESAMTPREIS
# index: 32	token: eur	word_id: 19	aligned label: 6	text label: O
# index: 33	token: ##o	word_id: 19	aligned label: 6	text label: O
# index: 34	token: durch	word_id: 20	aligned label: 6	text label: O
# index: 35	token: eine	word_id: 21	aligned label: 6	text label: O
# index: 36	token: privat	word_id: 22	aligned label: 11	text label: VERKAEUFER
# index: 37	token: ##person	word_id: 22	aligned label: 11	text label: VERKAEUFER
# index: 38	token: ,	word_id: 23	aligned label: 11	text label: VERKAEUFER
# index: 39	token: kauf	word_id: 24	aligned label: 6	text label: O
# index: 40	token: ##er	word_id: 24	aligned label: 6	text label: O
# index: 41	token: ist	word_id: 25	aligned label: 6	text label: O
# index: 42	token: die	word_id: 26	aligned label: 6	text label: O
# index: 43	token: w	word_id: 27	aligned label: 5	text label: KAEUFER
# index: 44	token: +	word_id: 27	aligned label: 5	text label: KAEUFER
# index: 45	token: m	word_id: 27	aligned label: 5	text label: KAEUFER
# index: 46	token: wohn	word_id: 28	aligned label: 5	text label: KAEUFER
# index: 47	token: ##bau	word_id: 28	aligned label: 5	text label: KAEUFER
# index: 48	token: g	word_id: 29	aligned label: 5	text label: KAEUFER
# index: 49	token: ##mb	word_id: 29	aligned label: 5	text label: KAEUFER
# index: 50	token: ##h	word_id: 29	aligned label: 5	text label: KAEUFER
# index: 51	token: .	word_id: 30	aligned label: 5	text label: KAEUFER
# index: 52	token: das	word_id: 31	aligned label: 6	text label: O
# index: 53	token: grund	word_id: 32	aligned label: 4	text label: IMMO_TYP
# index: 54	token: ##stu	word_id: 32	aligned label: 4	text label: IMMO_TYP
# index: 55	token: ##ck	word_id: 32	aligned label: 4	text label: IMMO_TYP
# index: 56	token: mit	word_id: 33	aligned label: 4	text label: IMMO_TYP
# index: 57	token: einer	word_id: 34	aligned label: 4	text label: IMMO_TYP
# index: 58	token: bau	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 59	token: ##fla	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 60	token: ##che	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 61	token: -	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 62	token: wohn	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 63	token: ##gebiet	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 64	token: -	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 65	token: wid	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 66	token: ##mung	word_id: 35	aligned label: 4	text label: IMMO_TYP
# index: 67	token: hat	word_id: 36	aligned label: 6	text label: O
# index: 68	token: eine	word_id: 37	aligned label: 6	text label: O
# index: 69	token: flach	word_id: 38	aligned label: 6	text label: O
# index: 70	token: ##e	word_id: 38	aligned label: 6	text label: O
# index: 71	token: von	word_id: 39	aligned label: 6	text label: O
# index: 72	token: 78	word_id: 40	aligned label: 2	text label: FLAECHE
# index: 73	token: ##1	word_id: 40	aligned label: 2	text label: FLAECHE
# index: 74	token: quadrat	word_id: 41	aligned label: 6	text label: O
# index: 75	token: ##meter	word_id: 41	aligned label: 6	text label: O
# index: 76	token: .	word_id: 42	aligned label: 6	text label: O
# index: 77	token: der	word_id: 43	aligned label: 6	text label: O
# index: 78	token: quadrat	word_id: 44	aligned label: 6	text label: O
# index: 79	token: ##meter	word_id: 44	aligned label: 6	text label: O
# index: 80	token: ##preis	word_id: 44	aligned label: 6	text label: O
# index: 81	token: des	word_id: 45	aligned label: 6	text label: O
# index: 82	token: bo	word_id: 46	aligned label: 6	text label: O
# index: 83	token: ##dens	word_id: 46	aligned label: 6	text label: O
# index: 84	token: liegt	word_id: 47	aligned label: 6	text label: O
# index: 85	token: bei	word_id: 48	aligned label: 6	text label: O
# index: 86	token: 85	word_id: 49	aligned label: 8	text label: QMPREIS
# index: 87	token: ##1	word_id: 49	aligned label: 8	text label: QMPREIS
# index: 88	token: ,	word_id: 49	aligned label: 8	text label: QMPREIS
# index: 89	token: 47	word_id: 49	aligned label: 8	text label: QMPREIS
# index: 90	token: eur	word_id: 50	aligned label: 6	text label: O
# index: 91	token: ##o	word_id: 50	aligned label: 6	text label: O
# index: 92	token: .	word_id: 51	aligned label: 6	text label: O
# index: 93	token: unterzeichnet	word_id: 52	aligned label: 6	text label: O
# index: 94	token: wurde	word_id: 53	aligned label: 6	text label: O
# index: 95	token: der	word_id: 54	aligned label: 6	text label: O
# index: 96	token: kauf	word_id: 55	aligned label: 6	text label: O
# index: 97	token: ##vertrag	word_id: 55	aligned label: 6	text label: O
# index: 98	token: am	word_id: 56	aligned label: 6	text label: O
# index: 99	token: 12	word_id: 57	aligned label: 1	text label: DATUM_VERTRAG
# index: 100	token: .	word_id: 57	aligned label: 1	text label: DATUM_VERTRAG
# index: 101	token: j	word_id: 58	aligned label: 1	text label: DATUM_VERTRAG
# index: 102	token: ##uli	word_id: 58	aligned label: 1	text label: DATUM_VERTRAG
# index: 103	token: .	word_id: 59	aligned label: 1	text label: DATUM_VERTRAG
# index: 104	token: die	word_id: 60	aligned label: 6	text label: O
# index: 105	token: verb	word_id: 61	aligned label: 6	text label: O
# index: 106	token: ##ucher	word_id: 61	aligned label: 6	text label: O
# index: 107	token: ##ung	word_id: 61	aligned label: 6	text label: O
# index: 108	token: datiert	word_id: 62	aligned label: 6	text label: O
# index: 109	token: mit	word_id: 63	aligned label: 6	text label: O
# index: 110	token: se	word_id: 64	aligned label: 0	text label: DATUM_VERBUECHERUNG
# index: 111	token: ##pt	word_id: 64	aligned label: 0	text label: DATUM_VERBUECHERUNG
# index: 112	token: ##ember	word_id: 64	aligned label: 0	text label: DATUM_VERBUECHERUNG
# index: 113	token: 2021	word_id: 65	aligned label: 0	text label: DATUM_VERBUECHERUNG
# index: 114	token: .	word_id: 66	aligned label: 0	text label: DATUM_VERBUECHERUNG
# index: 115	token: [SEP]	word_id: None	aligned label: -100	text label: SPECIAL TOKEN
# (116, 116, 116)

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["words"], truncation=True, is_split_into_words=True)
    all_labels = examples["ner_tags"]
    new_labels = []
    for i, labels in enumerate(all_labels):
        word_ids = tokenized_inputs.word_ids(i)
        new_labels.append(align_labels_with_tokens(labels, word_ids))
    tokenized_inputs["labels"] = new_labels
    return tokenized_inputs
#
tokenized_dataset = dataset.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=dataset.column_names
)
tokenized_dataset
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 140
# })

# %%
from datasets import ClassLabel
tokenized_dataset.features["labels"].feature.names = ClassLabel(names=ner_tag_names)
print(tokenized_dataset.features["labels"].feature.names)
tokenized_dataset.features["labels"].feature.names.names
# Out:
# ClassLabel(num_classes=12, names=['DATUM_VERBUECHERUNG', 'DATUM_VERTRAG', 'FLAECHE', 'GESAMTPREIS', 'IMMO_TYP', 'KAEUFER', 'O', 'ORT', 'QMPREIS', 'STRASSE', 'TERRASSENGROESSE', 'VERKAEUFER'], id=None)
# ['DATUM_VERBUECHERUNG',
#  'DATUM_VERTRAG',
#  'FLAECHE',
#  'GESAMTPREIS',
#  'IMMO_TYP',
#  'KAEUFER',
#  'O',
#  'ORT',
#  'QMPREIS',
#  'STRASSE',
#  'TERRASSENGROESSE',
#  'VERKAEUFER']

# %%
tokenized_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 140
# })

# %%
gNerDatasetDict = tokenized_dataset.train_test_split(shuffle=True, seed=42, test_size=0.25)
gNerDatasetDict.save_to_disk("gNERdataset")
gNerDatasetDict
# Out:
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# Flattening the indices:   0%|          | 0/1 [00:00<?, ?ba/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 105
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 35
#     })
# })

# %%
from datasets import load_from_disk
gNerDatasetCheck = load_from_disk("gNERdataset")
# Note, however, that the "ClassLabel" list with the names of the NER tags is not available, anymore!
gNerDatasetCheck
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 105
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 35
#     })
# })

# %% [markdown]
# $\checkmark$
