# %% [markdown]
# # Parse files (taken from Matthias)

# %%
import sklearn
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
import scipy.stats
import eli5
import json

with open("../annotations.jsonl") as jsonl_file:
    lines = jsonl_file.readlines()
annot = [json.loads(line) for line in lines]

# %%
print(json.dumps(annot[0], indent=4, sort_keys=True))
# Out:
# {
#     "_input_hash": 1497722439,
#     "_task_hash": 939340509,
#     "_timestamp": 1646733332,
#     "_view_id": "spans_manual",
#     "answer": "accept",
#     "meta": {
#         "pattern": "19, 19, 96",
#         "source": "vn"
#     },
#     "spans": [
#         {
#             "end": 8,
#             "label": "ORT",
#             "pattern": 2069086582,
#             "start": 0,
#             "text": "DORNBIRN",
#             "token_end": 0,
#             "token_start": 0
#         },
#         {
#             "end": 26,
#             "label": "STRASSE",
#             "start": 16,
#             "token_end": 3,
#             "token_start": 3
#         },
#         {
#             "end": 38,
#             "label": "ORT",
#             "pattern": 2069086582,
#             "start": 30,
#             "text": "Dornbirn",
#             "token_end": 5,
#             "token_start": 5
#         },
#         {
#             "end": 53,
#             "label": "FLAECHE",
#             "start": 48,
#             "token_end": 8,
#             "token_start": 8
#         },
#         {
#             "end": 80,
#             "label": "IMMO_TYP",
#             "start": 73,
#             "token_end": 11,
#             "token_start": 11
#         },
#         {
#             "end": 120,
#             "label": "QMPREIS",
#             "start": 113,
#             "token_end": 16,
#             "token_start": 16
#         },
#         {
#             "end": 225,
#             "label": "TERRASSENGROESSE",
#             "start": 221,
#             "token_end": 32,
#             "token_start": 32
#         },
#         {
#             "end": 312,
#             "label": "KAEUFER",
#             "start": 257,
#             "token_end": 41,
#             "token_start": 37
#         },
#         {
#             "end": 376,
#             "label": "VERKAEUFER",
#             "start": 351,
#             "token_end": 51,
#             "token_start": 49
#         },
#         {
#             "end": 409,
#             "label": "GESAMTPREIS",
#             "pattern": 949933890,
#             "start": 402,
#             "text": "398.040",
#             "token_end": 57,
#             "token_start": 57
#         },
#         {
#             "end": 468,
#             "label": "DATUM_VERTRAG",
#             "start": 455,
#             "token_end": 66,
#             "token_start": 65
#         },
#         {
#             "end": 512,
#             "label": "DATUM_VERBUECHERUNG",
#             "start": 499,
#             "token_end": 73,
#             "token_start": 72
#         }
#     ],
#     "text": "DORNBIRN In der Schulgasse in Dornbirn hat eine 71,93 Quadratmeter gro\u00dfe Wohnung f\u00fcr einen Quadratmeterpreis von 5533,71 Euro den Besitzer gewechselt. Dieser beinhaltet auch einen Pkw-Abstellplatz. K\u00e4ufer der Wohnung mit 9,86 Quadratmetern Terrasse ist die ValLiLean Beteiligungs- und Immobilienverwaltungs GmbH. Beim Verk\u00e4ufer handelt es sich um die Karrenblick Projekt GmbH.  Der Kaufpreis liegt bei 398.040 Euro. Unterzeichnet wurde der Kaufvertrag am 18. September. Die Verb\u00fccherung datiert mit Oktober 2020.",
#     "tokens": [
#         {
#             "end": 8,
#             "id": 0,
#             "start": 0,
#             "text": "DORNBIRN",
#             "ws": true
#         },
#         {
#             "end": 11,
#             "id": 1,
#             "start": 9,
#             "text": "In",
#             "ws": true
#         },
#         {
#             "end": 15,
#             "id": 2,
#             "start": 12,
#             "text": "der",
#             "ws": true
#         },
#         {
#             "end": 26,
#             "id": 3,
#             "start": 16,
#             "text": "Schulgasse",
#             "ws": true
#         },
#         {
#             "end": 29,
#             "id": 4,
#             "start": 27,
#             "text": "in",
#             "ws": true
#         },
#         {
#             "end": 38,
#             "id": 5,
#             "start": 30,
#             "text": "Dornbirn",
#             "ws": true
#         },
#         {
#             "end": 42,
#             "id": 6,
#             "start": 39,
#             "text": "hat",
#             "ws": true
#         },
#         {
#             "end": 47,
#             "id": 7,
#             "start": 43,
#             "text": "eine",
#             "ws": true
#         },
#         {
#             "end": 53,
#             "id": 8,
#             "start": 48,
#             "text": "71,93",
#             "ws": true
#         },
#         {
#             "end": 66,
#             "id": 9,
#             "start": 54,
#             "text": "Quadratmeter",
#             "ws": true
#         },
#         {
#             "end": 72,
#             "id": 10,
#             "start": 67,
#             "text": "gro\u00dfe",
#             "ws": true
#         },
#         {
#             "end": 80,
#             "id": 11,
#             "start": 73,
#             "text": "Wohnung",
#             "ws": true
#         },
#         {
#             "end": 84,
#             "id": 12,
#             "start": 81,
#             "text": "f\u00fcr",
#             "ws": true
#         },
#         {
#             "end": 90,
#             "id": 13,
#             "start": 85,
#             "text": "einen",
#             "ws": true
#         },
#         {
#             "end": 108,
#             "id": 14,
#             "start": 91,
#             "text": "Quadratmeterpreis",
#             "ws": true
#         },
#         {
#             "end": 112,
#             "id": 15,
#             "start": 109,
#             "text": "von",
#             "ws": true
#         },
#         {
#             "end": 120,
#             "id": 16,
#             "start": 113,
#             "text": "5533,71",
#             "ws": true
#         },
#         {
#             "end": 125,
#             "id": 17,
#             "start": 121,
#             "text": "Euro",
#             "ws": true
#         },
#         {
#             "end": 129,
#             "id": 18,
#             "start": 126,
#             "text": "den",
#             "ws": true
#         },
#         {
#             "end": 138,
#             "id": 19,
#             "start": 130,
#             "text": "Besitzer",
#             "ws": true
#         },
#         {
#             "end": 149,
#             "id": 20,
#             "start": 139,
#             "text": "gewechselt",
#             "ws": false
#         },
#         {
#             "end": 150,
#             "id": 21,
#             "start": 149,
#             "text": ".",
#             "ws": true
#         },
#         {
#             "end": 157,
#             "id": 22,
#             "start": 151,
#             "text": "Dieser",
#             "ws": true
#         },
#         {
#             "end": 168,
#             "id": 23,
#             "start": 158,
#             "text": "beinhaltet",
#             "ws": true
#         },
#         {
#             "end": 173,
#             "id": 24,
#             "start": 169,
#             "text": "auch",
#             "ws": true
#         },
#         {
#             "end": 179,
#             "id": 25,
#             "start": 174,
#             "text": "einen",
#             "ws": true
#         },
#         {
#             "end": 196,
#             "id": 26,
#             "start": 180,
#             "text": "Pkw-Abstellplatz",
#             "ws": false
#         },
#         {
#             "end": 197,
#             "id": 27,
#             "start": 196,
#             "text": ".",
#             "ws": true
#         },
#         {
#             "end": 204,
#             "id": 28,
#             "start": 198,
#             "text": "K\u00e4ufer",
#             "ws": true
#         },
#         {
#             "end": 208,
#             "id": 29,
#             "start": 205,
#             "text": "der",
#             "ws": true
#         },
#         {
#             "end": 216,
#             "id": 30,
#             "start": 209,
#             "text": "Wohnung",
#             "ws": true
#         },
#         {
#             "end": 220,
#             "id": 31,
#             "start": 217,
#             "text": "mit",
#             "ws": true
#         },
#         {
#             "end": 225,
#             "id": 32,
#             "start": 221,
#             "text": "9,86",
#             "ws": true
#         },
#         {
#             "end": 239,
#             "id": 33,
#             "start": 226,
#             "text": "Quadratmetern",
#             "ws": true
#         },
#         {
#             "end": 248,
#             "id": 34,
#             "start": 240,
#             "text": "Terrasse",
#             "ws": true
#         },
#         {
#             "end": 252,
#             "id": 35,
#             "start": 249,
#             "text": "ist",
#             "ws": true
#         },
#         {
#             "end": 256,
#             "id": 36,
#             "start": 253,
#             "text": "die",
#             "ws": true
#         },
#         {
#             "end": 266,
#             "id": 37,
#             "start": 257,
#             "text": "ValLiLean",
#             "ws": true
#         },
#         {
#             "end": 280,
#             "id": 38,
#             "start": 267,
#             "text": "Beteiligungs-",
#             "ws": true
#         },
#         {
#             "end": 284,
#             "id": 39,
#             "start": 281,
#             "text": "und",
#             "ws": true
#         },
#         {
#             "end": 306,
#             "id": 40,
#             "start": 285,
#             "text": "Immobilienverwaltungs",
#             "ws": true
#         },
#         {
#             "end": 312,
#             "id": 41,
#             "start": 307,
#             "text": "GmbH.",
#             "ws": true
#         },
#         {
#             "end": 317,
#             "id": 42,
#             "start": 313,
#             "text": "Beim",
#             "ws": true
#         },
#         {
#             "end": 327,
#             "id": 43,
#             "start": 318,
#             "text": "Verk\u00e4ufer",
#             "ws": true
#         },
#         {
#             "end": 335,
#             "id": 44,
#             "start": 328,
#             "text": "handelt",
#             "ws": true
#         },
#         {
#             "end": 338,
#             "id": 45,
#             "start": 336,
#             "text": "es",
#             "ws": true
#         },
#         {
#             "end": 343,
#             "id": 46,
#             "start": 339,
#             "text": "sich",
#             "ws": true
#         },
#         {
#             "end": 346,
#             "id": 47,
#             "start": 344,
#             "text": "um",
#             "ws": true
#         },
#         {
#             "end": 350,
#             "id": 48,
#             "start": 347,
#             "text": "die",
#             "ws": true
#         },
#         {
#             "end": 362,
#             "id": 49,
#             "start": 351,
#             "text": "Karrenblick",
#             "ws": true
#         },
#         {
#             "end": 370,
#             "id": 50,
#             "start": 363,
#             "text": "Projekt",
#             "ws": true
#         },
#         {
#             "end": 376,
#             "id": 51,
#             "start": 371,
#             "text": "GmbH.",
#             "ws": true
#         },
#         {
#             "end": 378,
#             "id": 52,
#             "start": 377,
#             "text": " ",
#             "ws": false
#         },
#         {
#             "end": 381,
#             "id": 53,
#             "start": 378,
#             "text": "Der",
#             "ws": true
#         },
#         {
#             "end": 391,
#             "id": 54,
#             "start": 382,
#             "text": "Kaufpreis",
#             "ws": true
#         },
#         {
#             "end": 397,
#             "id": 55,
#             "start": 392,
#             "text": "liegt",
#             "ws": true
#         },
#         {
#             "end": 401,
#             "id": 56,
#             "start": 398,
#             "text": "bei",
#             "ws": true
#         },
#         {
#             "end": 409,
#             "id": 57,
#             "start": 402,
#             "text": "398.040",
#             "ws": true
#         },
#         {
#             "end": 414,
#             "id": 58,
#             "start": 410,
#             "text": "Euro",
#             "ws": false
#         },
#         {
#             "end": 415,
#             "id": 59,
#             "start": 414,
#             "text": ".",
#             "ws": true
#         },
#         {
#             "end": 429,
#             "id": 60,
#             "start": 416,
#             "text": "Unterzeichnet",
#             "ws": true
#         },
#         {
#             "end": 435,
#             "id": 61,
#             "start": 430,
#             "text": "wurde",
#             "ws": true
#         },
#         {
#             "end": 439,
#             "id": 62,
#             "start": 436,
#             "text": "der",
#             "ws": true
#         },
#         {
#             "end": 451,
#             "id": 63,
#             "start": 440,
#             "text": "Kaufvertrag",
#             "ws": true
#         },
#         {
#             "end": 454,
#             "id": 64,
#             "start": 452,
#             "text": "am",
#             "ws": true
#         },
#         {
#             "end": 458,
#             "id": 65,
#             "start": 455,
#             "text": "18.",
#             "ws": true
#         },
#         {
#             "end": 468,
#             "id": 66,
#             "start": 459,
#             "text": "September",
#             "ws": false
#         },
#         {
#             "end": 469,
#             "id": 67,
#             "start": 468,
#             "text": ".",
#             "ws": true
#         },
#         {
#             "end": 473,
#             "id": 68,
#             "start": 470,
#             "text": "Die",
#             "ws": true
#         },
#         {
#             "end": 486,
#             "id": 69,
#             "start": 474,
#             "text": "Verb\u00fccherung",
#             "ws": true
#         },
#         {
#             "end": 494,
#             "id": 70,
#             "start": 487,
#             "text": "datiert",
#             "ws": true
#         },
#         {
#             "end": 498,
#             "id": 71,
#             "start": 495,
#             "text": "mit",
#             "ws": true
#         },
#         {
#             "end": 506,
#             "id": 72,
#             "start": 499,
#             "text": "Oktober",
#             "ws": true
#         },
#         {
#             "end": 512,
#             "id": 73,
#             "start": 507,
#             "text": "2020.",
#             "ws": false
#         }
#     ]
# }

# %%
print("instances:\n{}".format(len(annot)))
keys = [key for key in annot[0].keys()]
print("example instance:\n")
pri

print("\nall keys:\n{}".format(keys))
key_keys = ["text", "spans", "tokens"]
print("\nimportant keys:\n{}".format(key_keys))
print("\nexample text:\n{}".format(annot[0]["text"]))
n_examples = 5
print("\n{} example spans:".format(n_examples))
for span in annot[0]["spans"][:n_examples]:
    print("{}".format(span))
print("\n{} example tokens:".format(n_examples))
for token in annot[0]["tokens"][:n_examples]:
    print("{}".format(token))
# Out:
# instances:
# 140
#
# all keys:
# ['text', 'meta', '_input_hash', '_task_hash', 'spans', 'tokens', '_view_id', 'answer', '_timestamp']
#
# important keys:
# ['text', 'spans', 'tokens']
#
# example text:
# DORNBIRN In der Schulgasse in Dornbirn hat eine 71,93 Quadratmeter große Wohnung für einen Quadratmeterpreis von 5533,71 Euro den Besitzer gewechselt. Dieser beinhaltet auch einen Pkw-Abstellplatz. Käufer der Wohnung mit 9,86 Quadratmetern Terrasse ist die ValLiLean Beteiligungs- und Immobilienverwaltungs GmbH. Beim Verkäufer handelt es sich um die Karrenblick Projekt GmbH.  Der Kaufpreis liegt bei 398.040 Euro. Unterzeichnet wurde der Kaufvertrag am 18. September. Die Verbücherung datiert mit Oktober 2020.
#
# 5 example spans:
# {'text': 'DORNBIRN', 'start': 0, 'end': 8, 'pattern': 2069086582, 'token_start': 0, 'token_end': 0, 'label': 'ORT'}
# {'start': 16, 'end': 26, 'token_start': 3, 'token_end': 3, 'label': 'STRASSE'}
# {'text': 'Dornbirn', 'start': 30, 'end': 38, 'pattern': 2069086582, 'token_start': 5, 'token_end': 5, 'label': 'ORT'}
# {'start': 48, 'end': 53, 'token_start': 8, 'token_end': 8, 'label': 'FLAECHE'}
# {'start': 73, 'end': 80, 'token_start': 11, 'token_end': 11, 'label': 'IMMO_TYP'}
#
# 5 example tokens:
# {'text': 'DORNBIRN', 'start': 0, 'end': 8, 'id': 0, 'ws': True}
# {'text': 'In', 'start': 9, 'end': 11, 'id': 1, 'ws': True}
# {'text': 'der', 'start': 12, 'end': 15, 'id': 2, 'ws': True}
# {'text': 'Schulgasse', 'start': 16, 'end': 26, 'id': 3, 'ws': True}
# {'text': 'in', 'start': 27, 'end': 29, 'id': 4, 'ws': True}
